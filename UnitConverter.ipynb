# %%
convert_from = input("Enter Starting Unit of Measurement (inches, feet, yards): ")

convert_to  = input("Enter Converted Unit of Measurement (inches, feet, yards): ")

number_of_inches = input("Enter Starting Measurement in Inches: ")

number_of_feet   = input("Enter Starting Measurement in Feet: ")

number_of_yards  = input("Enter Starting Measurement in Yards: ")
# Out:
# Enter Starting Unit of Measurement (inches, feet, yards):  inches
# Enter Converted Unit of Measurement (inches, feet, yards):  feet
# Enter Starting Measurement in Inches:  24
# Enter Starting Measurement in Feet:  3
# Enter Starting Measurement in Yards:  1

# %%
convert_from = input("Enter Starting Unit of Measurement (inches, feet, yards): ")

convert_to  = input("Enter Converted Unit of Measurement (inches, feet, yards): ")

if convert_from.lower() in ["inches","in","Inch"]:
    number_of_inches = int(input("Enter Starting Measurement in Inches: "))
    if convert_to.lower() in ["feet","foot","ft"]:
        print("Result: " + str(number_of_inches) + ' Inches = ' + str(int(number_of_inches / 12)) + ' Feet')
    elif convert_to.lower() in ["yards","yard","yd","yds"]:
        print("Result: " + str(number_of_inches) + ' Inches = ' + str(int(number_of_inches / 36)) + ' Yards')
    else: 
        print("Your input was incorrect.")

elif convert_from.lower() in ["feet","foot","ft"]:
    number_of_feet = int(input("Enter Starting Measurement in Feet: "))
    if convert_to.lower() in ["inches","in","Inch"]:
        print("Result: " + str(number_of_feet) + ' Feet = ' + str(int(number_of_feet * 12)) + ' Inches')
    elif convert_to.lower() in ["yards","yard","yd","yds"]:
        print("Result: " + str(number_of_feet) + ' Feet = ' + str(int(number_of_feet / 3)) + ' Yards')
    else: 
        print("Your input was incorrect.")

elif convert_from.lower() in ["yards","yard","yd","yds"]:
    number_of_yards = int(input("Enter Starting Measurement in Yards: "))
    if convert_to.lower() in ["inches","in","Inch"]:
        print("Result: " + str(number_of_yards) + ' Yards = ' + str(int(number_of_yards * 36)) + ' Inches')
    elif convert_to.lower() in ["feet","foot","ft"]:
        print("Result: " + str(number_of_yards) + ' Yards = ' + str(int(number_of_yards * 12)) + ' Feet')
    else: 
        print("Please Enter either Inches, Feet, or Yards.")
# Out:
# Enter Starting Unit of Measurement (inches, feet, yards):  inches
# Enter Converted Unit of Measurement (inches, feet, yards):  ft
# Enter Starting Measurement in Inches:  36
# Result: 36 Inches = 3 Feet
